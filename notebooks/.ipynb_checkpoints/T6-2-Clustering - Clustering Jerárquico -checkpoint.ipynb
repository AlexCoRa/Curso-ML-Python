# %% [markdown]
# # Clustering jerárquico y dendogramas
#
# * X = dataset(array de n * m) de puntos a clusterizar.
# * n = número de datos.
# * m = numero de rasgos.
# * Z = array de enlaces del cluster con la información de las uniones.
# * k = números de clusters

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %%
np.random.seed(4711)
a = np.random.multivariate_normal([10,0],[[3,1],[1,4]], size = [100,])
b = np.random.multivariate_normal([0,20],[[3,1],[1,4]], size = [50,])
X = np.concatenate((a,b))
print(X.shape)
plt.scatter(X[:,0], X[:,1])
plt.show()
# Out:
# (150, 2)

# %%
Z = linkage(X, "ward")

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

# %%
c, coph_dist = cophenet(Z, pdist(X))
c
# Out:
# 0.9800148387574268

# %%
Z[0]
# Out:
# array([5.20000000e+01, 5.30000000e+01, 4.15105485e-02, 2.00000000e+00])

# %%
Z[1]
# Out:
# array([1.40000000e+01, 7.90000000e+01, 5.91375926e-02, 2.00000000e+00])

# %%
Z[13]
# Out:
# array([ 62.        , 152.        ,   0.17259953,   3.        ])

# %%
Z[152-len(X)] # cluster 152
# Out:
# array([33.        , 68.        ,  0.07106779,  2.        ])

# %%
idx = [33, 62, 68]
plt.figure(figsize=(10,8))
plt.scatter(X[:,0], X[:,1]) ## pintar todos los puntos
plt.scatter(X[idx,0], X[idx,1], c="r") ## destacamos en rojo los puntos interesantes
plt.show()

# %% [markdown]
# ## Representación gráfica de un dendograma

# %%
plt.figure(figsize=(25,10))
plt.title("Dendograma del clustering jerárquico")
plt.xlabel("Índice de las Muestras")
plt.ylabel("Distancias")
dendrogram(Z, leaf_rotation=90., leaf_font_size=8.0)
plt.show()

# %%
Z[-4:]
# Out:
# array([[290.        , 294.        ,  15.11533118,  76.        ],
#        [287.        , 292.        ,  17.11527362,  50.        ],
#        [293.        , 295.        ,  23.12198936, 100.        ],
#        [296.        , 297.        , 180.27043021, 150.        ]])

# %% [markdown]
# ## Truncar el dendograma

# %%
plt.figure(figsize=(25,10))
plt.title("Dendograma del clustering jerárquico truncado")
plt.xlabel("Índice de las Muestras")
plt.ylabel("Distancias")
dendrogram(Z, leaf_rotation=90., leaf_font_size=12.0, 
           truncate_mode="lastp", p=12, show_leaf_counts=True, show_contracted=True)
plt.show()

# %% [markdown]
# ## Dendograma tuneado

# %%
def dendogram_tune(*args, **kwargs):
    max_d = kwargs.pop("max_d", None)
    plt.figure(figsize=(25,10))
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)
    
    ddata = dendrogram(*args, **kwargs)
    
    if not kwargs.get('np_plot', False):
        plt.title("Clustering jerárquico con Dendograma truncado")
        plt.xlabel("Índice del Dataset (o tamaño del cluster)")
        plt.ylabel("Distancias")
        ## i = index, d = distance, c = color
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata["color_list"]):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x,y, 'o', c=c)
                plt.annotate('%.3g'%y, (x,y), xytext=(0, -5), 
                             textcoords="offset points", va = "top", ha="center")
    if max_d:
        plt.axhline(y = max_d, c="k")
    
    return ddata

# %%
dendogram_tune(Z, truncate_mode = 'lastp', 
               p=12, leaf_rotation=90., 
               leaf_font_size=20., show_contracted = True, annotate_above=10, max_d=50)
plt.show()
